# %%
import pandas as pd
import numpy as np
import torch

# %% [markdown]
# # IHDP

# %%
ihdp_mise = {
    "DRNet": [2.333, 2.797, 3.031, 2.963, 2.291, 2.569, 2.885, 2.488, 3.253, 2.466, 3.012, 3.001, 2.576, 3.043, 2.698, 2.655, 3.283, 3.029, 2.296, 2.751, 2.623, 2.964, 3.071, 3.119, 2.572, 2.358, 2.62, 2.439, 2.986, 2.491, 2.521, 2.522, 2.394, 2.795, 2.886, 2.718, 2.69, 2.846, 3.002, 2.528, 2.84, 2.36, 2.565, 2.337, 2.528, 3.005, 2.686, 3.016, 2.927, 2.707],
    "TARNet":[3.099, 2.968, 3.11, 2.835, 2.968, 3.275, 3.085, 3.081, 3.202, 3.014, 2.987, 3.103, 3.113, 3.149, 3.12, 3.031, 3.269, 3.005, 2.881, 3.07, 3.078, 2.968, 2.97, 3.065, 3.238, 3.003, 3.045, 3.03, 3.211, 3.117, 3.101, 3.133, 2.791, 3.272, 2.995, 3.235, 3.283, 3.026, 3.094, 3.095, 2.993, 3.017, 2.932, 2.987, 2.993, 2.992, 3.029, 3.107, 2.978, 3.239],
    "SciGAN": [0] * 50,
    "TransTEE": [2.3006520814760325, 2.1940829519414256, 2.7820855486487113, 1.8264720090929398, 2.0349447166937975, 2.355843797877949, 2.1524404753674373, 2.401666088364492, 2.2425431991379785, 1.9639246421387966, 1.9165072397463048, 2.368966019173766, 2.3390168874978223, 2.3019556902772913, 2.224185244083775, 2.2620786900547913, 2.4885738887965534, 2.114000946073582, 1.945764631192581, 2.126264329757709, 2.4147463634924478, 2.4151604501564696, 2.343928326549257, 2.2228360263411244, 2.6516032885784404, 2.2205855083738615, 2.2378561169118982, 2.3464867355261143, 2.5017993524661404, 2.327874567067564, 2.3630488780387084, 2.4166091947189146, 2.2133684736166277, 2.4592681838303037, 2.177613372479146, 2.4116384471972574, 2.6391286440793293, 2.366854452643846, 2.2144976857066254, 2.273543489797369, 2.1892921230388604, 2.2144976857066254, 2.281885185542866, 2.1168372634664196, 2.0371548787463363, 2.151278689523977, 2.1833460559425757, 2.137054047047009, 2.100238081742163, 2.3071627597549336],
    "VCNet": [2.223285857, 2.335380054723428, 2.295212408471164, 2.2494443758403984, 2.071231517720798, 1.9768662069042509, 2.523291501194422, 1.911543878648879, 2.3166786570433113, 2.3067292862405853, 2.286482013924448, 2.35732899697942, 2.2133684736166277, 2.2185580902919804, 2.104043725781382, 2.5522539058643834, 2.3196982562393758, 2.400416630503963, 2.390188277102873, 2.2391962843841986, 2.6877499883731746, 2.405202694161139, 2.3424346308915434, 2.3970815588961507, 2.2884492565927697, 2.6922109872742146, 2.054020447804744, 1.8939376969689368, 1.9287301521985911, 2.3920702330826327, 2.13658606192215, 2.023116407921205, 2.3853720883753127, 2.286263326915778, 2.465968369626829, 2.396247065725903, 2.4226019070412703, 2.5055937420100647, 2.131196846844514, 2.4805241381611265, 2.478911051248108, 1.9089263998384014, 1.9872090982078359, 1.998999749874922, 1.5665248162732692, 2.339444378479642, 2.3233596363886497, 2.2427661492005804, 2.083746625672133, 2.6330590574463004],
    "HSIC": [2.533, 2.019, 1.997, 2.118, 1.65, 1.77, 2.088, 1.53, 2.122, 1.9, 1.714, 1.986, 2.174, 2.205, 2.155, 1.835, 1.987, 1.939, 1.558, 2.037, 2.213, 1.98, 1.785, 2.004, 2.284, 2.011, 1.922, 1.806, 2.265, 1.789, 2.096, 2.321, 1.365, 2.204, 1.941, 1.985, 2.244, 1.957, 1.922, 1.579, 1.394, 2.052, 1.894, 1.881, 1.928, 1.931, 2.017, 2.325, 1.509, 2.148],
    "giks": [2.461, 1.887, 1.533, 1.555, 1.574, 2.231, 1.486, 2.187, 2.111, 1.875, 1.786, 1.904, 1.631, 1.407, 1.7, 1.938, 1.598, 1.752, 1.924, 2.243, 2.13, 1.116, 1.873, 2.011, 2.339, 2.01, 1.813, 1.77, 1.631, 1.99, 2.115, 1.977, 1.762, 2.188, 2.093, 1.752, 2.616, 1.822, 2.018, 1.918, 1.819, 2.085, 1.639, 1.691, 2.17, 1.665, 1.94, 1.932, 1.756, 2.119]
}

# %%
for k, v in ihdp_mise.items():
    print(k, np.mean(v))
# Out:
# DRNet 2.7307199999999994
# TARNet 3.06764
# SciGAN 0.0
# TransTEE 2.265583268109539
# VCNet 2.2633900592378757
# HSIC 1.9613800000000001
# giks 1.8908600000000002

# %% [markdown]
# # NEWS

# %%
news_mise = {
    "DRNet": np.sqrt([1.251, 1.256, 1.361, 1.317, 1.248, 1.3, 1.264, 1.241, 1.285, 1.234, 1.367, 1.248, 1.155, 1.181, 1.292, 1.397, 1.326, 1.217, 1.18, 1.257]),
    "TARNet": np.sqrt([1.356, 1.26, 1.368, 1.353, 1.398, 1.345, 1.329, 1.305, 1.486, 1.282, 1.398, 1.329, 1.317, 1.507, 1.326, 1.388, 1.302, 1.314, 1.286, 1.412]),
    "SciGAN": [0] * 20,
    "TransTEE": np.sqrt( [1.627, 1.543, 1.639, 1.546, 1.504, 1.523, 1.596, 1.521, 1.592, 1.504, 1.504, 1.465, 1.48, 1.57, 1.535, 1.538, 1.481, 1.498, 1.492, 1.531]),
    "VCNet": np.sqrt([1.165,1.256,1.244,1.201,1.264,1.169,1.253,1.202,1.223,1.236,1.256,1.162,1.364,1.361,1.18,1.197,1.168,1.198,1.227,1.183]),
    "HSIC": [1.128, 1.104, 1.104, 1.136, 1.136, 1.07, 1.052, 1.126, 1.067, 1.094, 1.117, 1.133, 1.144, 1.079, 1.091, 1.09, 1.143, 1.079, 1.09, 1.103],
    "giks": [1.089, 1.056, 1.085, 1.098, 1.063, 1.093, 1.066, 1.08, 1.067, 1.085, 1.101, 1.08, 1.073, 1.072, 1.07, 1.071, 1.093, 1.074, 1.084, 1.075]
}

# %%
for k, v in news_mise.items():
    print(k, np.mean(v))
# Out:
# DRNet 1.12609841153416
# TARNet 1.1629021117675402
# SciGAN 0.0
# TransTEE 1.2385828900314972
# VCNet 1.106717914436868
# HSIC 1.1043
# giks 1.07875

# %% [markdown]
# # TCGA - 0

# %%
tcga_0_mise = {
    "DRNet": [1.692909788,1.635845521,1.715212824,1.615051364,1.728920165,1.694667431,1.640439881,1.689839105,1.67853203,1.63878929],
    "TARNet": [1.684383651,1.703272903,1.709886901,1.674581643,1.64238917,1.689180664,1.665410533,1.618253841,1.694247144,1.69342714],
    "SciGAN": [1.7361781334442723, 2.283364888518465, 1.8174296437579511, 3.5526969983361614, 2.6277264396679234, 3.3178927172834385, 3.788407676963445, 2.6707028876493832, 3.785298378346034, 1.855564156808467],
    "TransTEE": [0.174744326,0.121878699,0.158223425,0.214513938,0.177014545,0.178811371,0.134365359,0.181699829,0.152696054,0.143810865],
    "VCNet": [0.118555567,0.14493252,0.231338541,0.197758622,0.191489653,0.118835364,0.116565464,0.14791299,0.13116323,0.227904144],
    "HSIC": [0.210200, 0.168180, 0.2824457, 0.1139, 0.127595, 0.16700, 0.1358577, 0.12659, 0.1260, 0.184312],
    "giks": [0.14201330386892821, 0.10433045226477788, 0.2319697474945072, 0.13377963257599482, 0.1738935111414056, 0.19030569056506458, 0.10152972942985729, 0.12255420654931093, 0.10637421346598055, 0.21444508551920144]
}

# %%
for k, v in tcga_0_mise.items():
    print(k, np.mean(v))
# Out:
# DRNet 1.6730207399
# TARNet 1.677503359
# SciGAN 2.743526192077554
# TransTEE 0.1637758411
# VCNet 0.1626456095
# HSIC 0.16420804
# giks 0.15211955728750287

# %% [markdown]
# # TCGA - 1

# %%
tcga_1_mise = {
    "DRNet": [1.424779056,1.496709078,1.344137402,1.340890132,1.375474554,1.438657275,1.402398086,1.463032887,1.425154717,1.461060167],
    "TARNet": [1.421992628,1.493610302,1.459807732,1.473250393,1.436611919,1.482113685,1.485404785,1.542761129,1.396761631,1.461082672],
    "SciGAN": [1.3788444008713232, 1.4830844863113433, 0.9516516959143304, 2.329199494121144, 0.4488721719625197, 0.31106966390402147, 0.9684682541424992, 0.4091334538757568, 0.4068423630576306, 0.38117130685841316],
    "TransTEE": [0.146491709,0.185783733,0.089347898,0.085349157,0.179996455,0.151914607,0.165774351,0.159920232,0.14827745,0.143795564],
    "VCNet": [0.076737938,0.092138077,0.101907416,0.123790677,0.104460515,0.093003125,0.100447811,0.106394259,0.091037157,0.089914238],
    "HSIC": [0.09454, 0.0835693, 0.115151, 0.102012, 0.122629, 0.09310, 0.085390, 0.0780, 0.09485426, 0.087320],
    "giks": [0.08781996207822351, 0.08943434788135776, 0.09097728916063737, 0.08584643538598047, 0.11308012244092255, 0.08539998608611966, 0.0846039296213046, 0.08612503413259297, 0.08185113322324991, 0.07498095060389276]
}

# %%
for k, v in tcga_1_mise.items():
    print(k, np.mean(v))
# Out:
# DRNet 1.4172293353999998
# TARNet 1.4653396876
# SciGAN 0.9068337291018983
# TransTEE 0.14566511559999998
# VCNet 0.0979831213
# HSIC 0.09565655599999999
# giks 0.08801191906142816

# %% [markdown]
# # TCGA - 2

# %%
tcga_2_mise = {
    "DRNet": [3.374794714,3.428263492,3.341258714,3.184703352,3.496070787,3.316341141,3.369721789,3.428102606,3.330123445,3.379379189],
    "TARNet": [3.475696411,3.499615449,3.395689503,3.372871166,3.44358137,3.360566791,3.374521034,3.396321365,3.287407294,3.355078765],
    "SciGAN": [0.7375727517897579, 0.7651010232655996, 0.704330427879454, 1.072479053395045, 1.985016425169606, 0.6901096639959842, 5.541403662960832, 0.6759628034018189, 0.5974091972067552, 0.8194982686878545],
    "TransTEE": [0.186928969,0.204307274,0.223321816,0.196708783,0.202447781,0.209701126,0.183551704,0.19033032,0.207710561,0.207623762],
    "VCNet": [0.133622077,0.172287352,0.161080534,0.171570758,0.175280127,0.158455341,0.138179957,0.130991579,0.13751888,0.139695196],
    "HSIC": [0.13546, 0.1223, 0.147421, 0.14766, 0.1403863, 0.146454, 0.12107, 0.13216, 0.17334, 0.175797],
    "giks": [0.11275327706077094, 0.14049526781201374, 0.12302686276590565, 0.12522333444085712, 0.16999191236890837, 0.12374989777677876, 0.12163665196335045, 0.12093321834474463, 0.11833220544488347, 0.11402467819162693]
}

# %%
for k, v in tcga_2_mise.items():
    print(k, np.mean(v))
# Out:
# DRNet 3.3648759229
# TARNet 3.3961349147999997
# SciGAN 1.3588883277752708
# TransTEE 0.2012632096
# VCNet 0.15186818009999997
# HSIC 0.14420483
# giks 0.12701673061698399

# %% [markdown]
# # This is for staged Training

# %%
ihdp_staged = {
    "Factual": [2.701, 1.911, 1.888, 1.651, 1.561, 2.229, 1.852, 2.027, 2.278, 2.076, 1.923, 2.002, 1.896, 1.665, 1.971, 2.176, 1.719, 1.746, 2.059, 2.282, 2.391, 1.348, 2.019, 2.077, 2.234, 1.913, 2.344, 1.91, 1.688, 2.251, 2.447, 1.988, 1.835, 2.293, 2.311, 2.112, 2.615, 2.09, 2.072, 2.31, 1.865, 2.266, 2.029, 1.927, 2.554, 1.695, 2.129, 1.991, 2.148, 2.355],
    "gi": [2.54, 1.927, 1.592, 1.628, 1.645, 2.335, 1.605, 2.207, 2.662, 1.788, 1.727, 1.99, 1.771, 1.574, 1.824, 1.938, 1.639, 1.738, 1.937, 1.963, 2.136, 1.048, 1.882, 1.957, 2.229, 2.099, 1.707, 1.791, 1.597, 1.985, 2.138, 1.937, 1.559, 2.223, 2.246, 1.828, 2.459, 1.841, 1.936, 2.027, 1.794, 2.136, 1.731, 1.768, 2.294, 1.645, 1.909, 1.923, 1.79, 2.225],
    "ks": [2.608, 1.896, 1.758, 1.577, 1.715, 2.157, 1.563, 1.974, 2.09, 1.903, 1.83, 1.987, 1.93, 1.461, 1.783, 2.026, 1.578, 1.805, 1.883, 2.512, 2.259, 1.239, 1.981, 1.904, 2.196, 1.962, 2.196, 1.956, 1.676, 2.167, 2.065, 2.06, 1.729, 2.275, 2.126, 1.909, 2.5, 1.915, 2.012, 2.122, 1.845, 2.184, 1.822, 1.848, 2.172, 1.598, 2.04, 1.944, 1.951, 2.324],
    "giks": ihdp_mise["giks"]
}

# %%
for k, v in ihdp_staged.items():
    print(k, np.mean(v))
# Out:
# Factual 2.0564
# gi 1.9173999999999998
# ks 1.96026
# giks 1.8908600000000002

# %%
news_staged = {
    "Factual": [1.088, 1.079, 1.104, 1.116, 1.069, 1.093, 1.063, 1.094, 1.064, 1.103, 1.123, 1.094, 1.105, 1.081, 1.101, 1.086, 1.104, 1.12, 1.122, 1.081],
    "gi": [1.107, 1.066, 1.082, 1.103, 1.063, 1.072, 1.069, 1.072, 1.056, 1.096, 1.099, 1.076, 1.078, 1.078, 1.083, 1.059, 1.096, 1.082, 1.079, 1.078],
    "ks": [1.115, 1.07, 1.079, 1.098, 1.046, 1.094, 1.063, 1.084, 1.053, 1.093, 1.105, 1.075, 1.081, 1.077, 1.066, 1.087, 1.118, 1.07, 1.094, 1.082],
    "giks": news_mise["giks"]
}

# %%
for k, v in news_staged.items():
    print(k, np.mean(v))
# Out:
# Factual 1.0945
# gi 1.0797
# ks 1.0825
# giks 1.07875

# %%
tcga_0_staged = {
    "Factual": [0.13096911312352197, 0.149873572849811, 0.3441444259452664, 0.1505487126011818, 0.24547269355869789, 0.22814134209272127, 0.1280925153525786, 0.16112205588967682, 0.12163266138989298, 0.21280060228312359],
    "gi": [0.13642039092846656, 0.14451654726775381, 0.3081897090597315, 0.12083490666851054, 0.17193208473935032, 0.19548558892739806, 0.1205606035455636],
    "ks": [0.1540860997168695, 0.14612306324520777, 0.3003948508642947, 0.1367200436499997, 0.20026695188401078, 0.1928706654782285, 0.14462823431396377, 0.13427329025315254, 0.11943448128571436, 0.1744684864876101],
    "giks": tcga_0_mise["giks"]
}

# %%
for k, v in tcga_0_staged.items():
    print(k, np.mean(v))
# Out:
# Factual 0.18727976950864722
# gi 0.17113426159096773
# ks 0.1703266167179052
# giks 0.15211955728750287

# %%
tcga_1_staged = {
    "Factual": [0.09846180140950184, 0.09528927115870775, 0.09770317925129195, 0.09332980355682598, 0.12798974049771702, 0.08876178335079526, 0.08582001289043192, 0.09358285926455095, 0.09322944072370996, 0.0806580027494465],
    "gi": [0.07916999893319257, 0.07021822256964208, 0.1253495964911982, 0.08978654071091366, 0.10652427080196533, 0.08898856407307419, 0.08023424474940344, 0.06935913798389855, 0.07901414963450386, 0.07199254941759264],
    "ks": [0.07517975236415338, 0.07902486008117061, 0.12400459258323333, 0.08482322063713803, 0.10046648316037442, 0.08883369931836867, 0.08392766706512574, 0.07458307800414975, 0.07451387564248545, 0.07480009599315418],
    "giks": tcga_1_mise["giks"]
}

# %%
for k, v in tcga_1_staged.items():
    print(k, np.mean(v))
# Out:
# Factual 0.09548258948529792
# gi 0.08606372753653843
# ks 0.08601573248493535
# giks 0.08801191906142816

# %%
tcga_2_staged = {
    "Factual": [0.12862336885466702, 0.13685957851145497, 0.1852187995081243, 0.17170823354831702, 0.28076292853050716, 0.1906791623218204, 0.14049010057792466, 0.1430347193046196, 0.13630420900362658, 0.1399779260542297],
    "gi": [0.12232137822766101, 0.171898793684036, 0.13930350511631348, 0.14474987309306642, 0.22123148962698705, 0.1400197098912811, 0.12550448187311303, 0.13208890848015048, 0.12594981052454682, 0.12905631593577008],
    "ks": [0.1262517722695626, 0.14289123335631987, 0.18241102521153246, 0.13613069326051022, 0.23354130426479147, 0.16481200628538223, 0.14090237259391877, 0.14808133347494043, 0.13668773538133105, 0.13628575980018076],
    "giks": tcga_2_mise["giks"]
}

# %%
for k, v in tcga_2_staged.items():
    print(k, np.mean(v))
# Out:
# Factual 0.16536590262152917
# gi 0.14521242664529255
# ks 0.154799523589847
# giks 0.12701673061698399

# %%
from scipy.stats import ttest_ind
def t_test(x, y, alternative="lesser"):
    # Code taken from: https://stackoverflow.com/questions/15984221/how-to-perform-two-sample-one-tailed-t-test-with-numpy-scipy
    if type(x) == torch.Tensor:
        x = x.numpy()
    if type(y) == torch.Tensor:
        y = y.numpy()
    _, double_p = ttest_ind(x, y, equal_var=False)
    if alternative == "both-sided":
        pval = double_p
    elif alternative == "greater":
        if np.mean(x) > np.mean(y):
            pval = double_p / 2.0
        else:
            pval = 1.0 - double_p / 2.0
    elif alternative == "lesser":
        if np.mean(x) < np.mean(y):
            pval = double_p / 2.0
        else:
            pval = 1.0 - double_p / 2.0
    return pval

# %%
def prepare_ds(res_dict):
    result = []
    compare = res_dict['giks']
    for key in ['DRNet', 'TARNet', "SciGAN", 'TransTEE', 'VCNet', 'HSIC', 'giks']:
        base = res_dict[key]
        if key != "giks":
            if key == "HSIC":
                result.append(f"second(({round(np.mean(base), 3)} pm {round(t_test(compare, base), 3)}))")
            else:
                result.append(f"{round(np.mean(base), 3)} pm {round(t_test(compare, base), 3)}")
        else:
            result.append(f"first(({round(np.mean(base), 3)}))")
    return result

# %%
main_table = {
    "TCGA-0": prepare_ds(tcga_0_mise),
    "TCGA-1": prepare_ds(tcga_1_mise),
    "TCGA-2": prepare_ds(tcga_2_mise),
    "IHDP": prepare_ds(ihdp_mise),
    "NEWS": prepare_ds(news_mise)
}

print(pd.DataFrame(main_table).T.to_latex())
# Out:
# \begin{tabular}{llllllll}
# \toprule
# {} &             0 &             1 &               2 &               3 &               4 &                         5 &               6 \\
# \midrule
# TCGA-0 &  1.673 pm 0.0 &  1.678 pm 0.0 &    2.744 pm 0.0 &  0.164 pm 0.256 &   0.163 pm 0.31 &  second((0.164 pm 0.297)) &  first((0.152)) \\
# TCGA-1 &  1.417 pm 0.0 &  1.465 pm 0.0 &  0.907 pm 0.002 &    0.146 pm 0.0 &  0.098 pm 0.032 &  second((0.096 pm 0.089)) &  first((0.088)) \\
# TCGA-2 &  3.365 pm 0.0 &  3.396 pm 0.0 &  1.359 pm 0.015 &    0.201 pm 0.0 &  0.152 pm 0.002 &  second((0.144 pm 0.022)) &  first((0.127)) \\
# IHDP   &  2.731 pm 0.0 &  3.068 pm 0.0 &      0.0 pm 1.0 &    2.266 pm 0.0 &    2.263 pm 0.0 &  second((1.961 pm 0.091)) &  first((1.891)) \\
# NEWS   &  1.126 pm 0.0 &  1.163 pm 0.0 &      0.0 pm 1.0 &    1.239 pm 0.0 &    1.107 pm 0.0 &    second((1.104 pm 0.0)) &  first((1.079)) \\
# \bottomrule
# \end{tabular}

# %%
def prepare_ablation(res_dict):
    result = []
    compare = res_dict['giks']
    for key in ['Factual', 'gi', 'ks', 'giks']:
        base = res_dict[key]
        if key != "giks":
            result.append(f"{round(np.mean(base), 3)} pm {round(t_test(compare, base), 3)}")
        else:
            result.append(f"{round(np.mean(base), 3)}")
    return result

# %%
ablation_table = {
    "TCGA-0": prepare_ablation(tcga_0_staged),
    "TCGA-1": prepare_ablation(tcga_1_staged),
    "TCGA-2": prepare_ablation(tcga_2_staged),
    "IHDP": prepare_ablation(ihdp_staged),
    "NEWS": prepare_ablation(news_staged)
}

print(pd.DataFrame(ablation_table).T.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} &               0 &               1 &               2 &      3 \\
# \midrule
# TCGA-0 &  0.187 pm 0.105 &  0.171 pm 0.265 &   0.17 pm 0.214 &  0.152 \\
# TCGA-1 &   0.095 pm 0.08 &  0.086 pm 0.617 &  0.086 pm 0.631 &  0.088 \\
# TCGA-2 &  0.165 pm 0.015 &   0.145 pm 0.06 &  0.155 pm 0.015 &  0.127 \\
# IHDP   &  2.056 pm 0.002 &  1.917 pm 0.321 &   1.96 pm 0.102 &  1.891 \\
# NEWS   &  1.094 pm 0.002 &   1.08 pm 0.411 &   1.082 pm 0.23 &  1.079 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Sampling Ablations

# %%
ihdp_sampling = {
    "uniform": ihdp_mise["giks"],
    "marginal": [2.479, 1.837, 1.492, 1.685, 1.588, 2.296, 1.631, 2.197, 1.964, 1.737, 1.852, 1.973, 1.693, 1.469, 1.652, 1.864, 1.69, 1.702, 2.0, 2.012, 2.01, 1.066, 1.909, 1.932, 2.372, 2.044, 1.813, 1.767, 1.442, 2.051, 2.234, 1.871, 1.733, 2.226, 2.043, 1.749, 2.469, 1.855, 2.057, 1.928, 1.879, 2.081, 2.139, 1.971, 2.076, 1.648, 1.907, 1.904, 1.846, 2.256],
    "inv": [2.423, 1.918, 1.534, 1.874, 1.528, 2.173, 1.506, 2.258, 2.133, 1.84, 1.781, 1.923, 1.677, 1.433, 1.759, 1.971, 1.45, 1.733, 1.942, 2.009, 1.993, 1.168, 1.859, 2.07, 2.301, 1.951, 1.754, 1.829, 1.538, 2.011, 2.112, 2.052, 1.771, 2.178, 2.133, 1.844, 2.589, 1.818, 2.04, 2.076, 1.84, 2.07, 1.737, 1.763, 2.186, 1.771, 1.89, 1.916, 1.812, 2.225]
}

# %%
news_sampling = {
    "uniform": news_mise["giks"],
    "marginal": [1.115, 1.065, 1.073, 1.126, 1.074, 1.066, 1.068, 1.085, 1.082, 1.123, 1.086, 1.084, 1.081, 1.09, 1.069, 1.08, 1.106, 1.065, 1.091, 1.084],
    "inv": [1.115, 1.07, 1.079, 1.098, 1.046, 1.097, 1.063, 1.084, 1.052, 1.093, 1.095, 1.076, 1.08, 1.078, 1.066, 1.079, 1.115, 1.066, 1.08, 1.077]
}

# %%
def prepare_sampling(res_dict):
    result = []
    compare = res_dict['uniform']
    for key in ['marginal', 'inv', 'uniform']:
        base = res_dict[key]
        if key != "uniform":
            result.append(f"{round(np.mean(base), 3)} pm {round(t_test(compare, base), 3)}")
        else:
            result.append(f"{round(np.mean(base), 3)}")
    return result

# %%
sampling_table = {
    "IHDP": prepare_sampling(ihdp_sampling),
    "NEWS": prepare_sampling(news_sampling)
}

print(pd.DataFrame(sampling_table).to_latex())
# Out:
# \begin{tabular}{lll}
# \toprule
# {} &            IHDP &            NEWS \\
# \midrule
# 0 &  1.902 pm 0.421 &  1.086 pm 0.087 \\
# 1 &   1.903 pm 0.41 &   1.08 pm 0.365 \\
# 2 &           1.891 &           1.079 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Kernel Expts

# %%
kernel_dict = {
    "ntk": [2.183, 1.953, 2.217, 1.527, 1.747],
    "cos": [2.311, 1.793, 2.08, 1.343, 1.685],
    "dot": [2.278, 1.837, 2.124, 1.307, 1.864]
}

# %%
def prepare_kernel(res_dict):
    result = []
    compare = res_dict['cos']
    for key in ['ntk', 'dot', 'cos']:
        base = res_dict[key]
        if key != "cos":
            result.append(f"{round(np.mean(base), 3)} pm {round(t_test(compare, base), 3)}")
        else:
            result.append(f"{round(np.mean(base), 3)}")
    return result

# %%
kernel_table = {
    "::": prepare_kernel(kernel_dict)
}

print(pd.DataFrame(kernel_table).to_latex())
# Out:
# \begin{tabular}{ll}
# \toprule
# {} &              :: \\
# \midrule
# 0 &  1.925 pm 0.353 \\
# 1 &  1.882 pm 0.435 \\
# 2 &           1.842 \\
# \bottomrule
# \end{tabular}
